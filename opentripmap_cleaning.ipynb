# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
opentripmap = pd.read_csv("opentripmap.csv")
opentripmap
# Out:
#            id          xid                                              name  \
# 0     3818906  N3429300976                              Гостиница «Бристоль»
# 1     3982337  N4549651178                     амакс курорт ""старая русса""
# 2     3994795  N6152315069                                   порт на невском
# 3     9522713     R6938164                                       Тихий океан
# 4     9595921    R10572941  hotel metropol palace, a luxury collection hotel
# ...       ...          ...                                               ...
# 2217  9580096   W591351418                                        93hotel.ru
# 2218  1770034  N4315875189                                           Ванатур
# 2219  9580086   W591347445                                       отель идеал
# 2220  9580090   W591347441                                            Кронос
# 2221  1769972  N4299081995                           гостиница золотые пески
#
#        longitude   latitude      distance  rate                osm  \
# 0      38.934727  47.211983           NaN     7    node/3429300976
# 1      31.367519  57.985519           NaN     7    node/4549651178
# 2      30.353550  59.933083           NaN     7    node/6152315069
# 3     131.879669  43.117100           NaN     7   relation/6938164
# 4      20.473774  44.806789           NaN     7  relation/10572941
# ...          ...        ...           ...   ...                ...
# 2217   37.250084  44.986610  11430.177488     1      way/591351418
# 2218   37.255215  44.988403  11431.631234     1    node/4315875189
# 2219   37.247829  44.985825  11435.714678     2      way/591347445
# 2220   37.247273  44.985680  11442.261144     1      way/591347441
# 2221   37.254368  44.988243  11443.982434     2    node/4299081995
#
#                                                   kinds  country
# 0                            accomodations,other_hotels   Россия
# 1                                 accomodations,resorts   Россия
# 2                    accomodations,hostels,guest_houses   Россия
# 3     architecture,historic_architecture,accomodatio...   Россия
# 4                            accomodations,other_hotels  Unknown
# ...                                                 ...      ...
# 2217                         accomodations,other_hotels   Россия
# 2218                         guest_houses,accomodations   Россия
# 2219                         accomodations,other_hotels   Россия
# 2220                         accomodations,other_hotels   Россия
# 2221                         accomodations,other_hotels   Россия
#
# [2222 rows x 10 columns]

# %% [markdown]
# Согласно [документации OpenTripMap API](https://dev.opentripmap.org/docs):
# - osm - идентификатор OpenStreetMap объекта
# - xid - Уникальный идентификатор объекта в системе OpenTripMap
#
# Для нашего проекта они не имеют бизнес-ценности, поэтому спокойно удаляем

# %%
opentripmap = opentripmap.drop(columns=['osm'])
opentripmap = opentripmap.drop(columns=['xid'])

# %% [markdown]
# Рассмотрим отели и гостиницы, у которых неизвестно страна расположения

# %%
opentripmap['country'] = opentripmap['country'].replace("Unknown", np.nan)
opentripmap
# Out:
#            id                                              name   longitude  \
# 0     3818906                              Гостиница «Бристоль»   38.934727
# 1     3982337                     амакс курорт ""старая русса""   31.367519
# 2     3994795                                   порт на невском   30.353550
# 3     9522713                                       Тихий океан  131.879669
# 4     9595921  hotel metropol palace, a luxury collection hotel   20.473774
# ...       ...                                               ...         ...
# 2217  9580096                                        93hotel.ru   37.250084
# 2218  1770034                                           Ванатур   37.255215
# 2219  9580086                                       отель идеал   37.247829
# 2220  9580090                                            Кронос   37.247273
# 2221  1769972                           гостиница золотые пески   37.254368
#
#        latitude      distance  rate  \
# 0     47.211983           NaN     7
# 1     57.985519           NaN     7
# 2     59.933083           NaN     7
# 3     43.117100           NaN     7
# 4     44.806789           NaN     7
# ...         ...           ...   ...
# 2217  44.986610  11430.177488     1
# 2218  44.988403  11431.631234     1
# 2219  44.985825  11435.714678     2
# 2220  44.985680  11442.261144     1
# 2221  44.988243  11443.982434     2
#
#                                                   kinds country
# 0                            accomodations,other_hotels  Россия
# 1                                 accomodations,resorts  Россия
# 2                    accomodations,hostels,guest_houses  Россия
# 3     architecture,historic_architecture,accomodatio...  Россия
# 4                            accomodations,other_hotels     NaN
# ...                                                 ...     ...
# 2217                         accomodations,other_hotels  Россия
# 2218                         guest_houses,accomodations  Россия
# 2219                         accomodations,other_hotels  Россия
# 2220                         accomodations,other_hotels  Россия
# 2221                         accomodations,other_hotels  Россия
#
# [2222 rows x 8 columns]

# %%
missed=opentripmap.isnull().sum()
missed
# Out:
# id             0
# name         273
# longitude      0
# latitude       0
# distance     218
# rate           0
# kinds          0
# country      765
# dtype: int64

# %% [markdown]
# Всего было найдено 765 строк, где не было заполнено страны. Выясним, координаты каких отелей находятся в пределах России
# Если координата отеля в пределах России, в столбец country запишем Russia, иначе Other

# %%
def is_in_russia(latitude, longitude):
    if 41.0 <= latitude <= 82.0 and 19.0 <= longitude <= 180.0:
        return True
    else:
        return False

mask = opentripmap['country'].isna()

opentripmap.loc[mask, 'country'] = opentripmap[mask].apply(
    lambda row: "Россия" if is_in_russia(row['latitude'], row['longitude']) else "Other",
    axis=1
)

# %%
opentripmap['country'] = opentripmap['country'].replace("Other", np.nan)
opentripmap
# Out:
#            id                                              name   longitude  \
# 0     3818906                              Гостиница «Бристоль»   38.934727
# 1     3982337                     амакс курорт ""старая русса""   31.367519
# 2     3994795                                   порт на невском   30.353550
# 3     9522713                                       Тихий океан  131.879669
# 4     9595921  hotel metropol palace, a luxury collection hotel   20.473774
# ...       ...                                               ...         ...
# 2217  9580096                                        93hotel.ru   37.250084
# 2218  1770034                                           Ванатур   37.255215
# 2219  9580086                                       отель идеал   37.247829
# 2220  9580090                                            Кронос   37.247273
# 2221  1769972                           гостиница золотые пески   37.254368
#
#        latitude      distance  rate  \
# 0     47.211983           NaN     7
# 1     57.985519           NaN     7
# 2     59.933083           NaN     7
# 3     43.117100           NaN     7
# 4     44.806789           NaN     7
# ...         ...           ...   ...
# 2217  44.986610  11430.177488     1
# 2218  44.988403  11431.631234     1
# 2219  44.985825  11435.714678     2
# 2220  44.985680  11442.261144     1
# 2221  44.988243  11443.982434     2
#
#                                                   kinds country
# 0                            accomodations,other_hotels  Россия
# 1                                 accomodations,resorts  Россия
# 2                    accomodations,hostels,guest_houses  Россия
# 3     architecture,historic_architecture,accomodatio...  Россия
# 4                            accomodations,other_hotels  Россия
# ...                                                 ...     ...
# 2217                         accomodations,other_hotels  Россия
# 2218                         guest_houses,accomodations  Россия
# 2219                         accomodations,other_hotels  Россия
# 2220                         accomodations,other_hotels  Россия
# 2221                         accomodations,other_hotels  Россия
#
# [2222 rows x 8 columns]

# %%
opentripmap.isnull().sum()
# Out:
# id             0
# name         273
# longitude      0
# latitude       0
# distance     218
# rate           0
# kinds          0
# country        0
# dtype: int64

# %% [markdown]
# Выяснилось, что все отели со страной Unknown находятся в России. Продолжаем работу

# %% [markdown]
# Удалим все строки, где названия отелей не заполнены

# %%
opentripmap.dropna(subset=['name'], inplace=True)
opentripmap
# Out:
#            id                                              name   longitude  \
# 0     3818906                              Гостиница «Бристоль»   38.934727
# 1     3982337                     амакс курорт ""старая русса""   31.367519
# 2     3994795                                   порт на невском   30.353550
# 3     9522713                                       Тихий океан  131.879669
# 4     9595921  hotel metropol palace, a luxury collection hotel   20.473774
# ...       ...                                               ...         ...
# 2217  9580096                                        93hotel.ru   37.250084
# 2218  1770034                                           Ванатур   37.255215
# 2219  9580086                                       отель идеал   37.247829
# 2220  9580090                                            Кронос   37.247273
# 2221  1769972                           гостиница золотые пески   37.254368
#
#        latitude      distance  rate  \
# 0     47.211983           NaN     7
# 1     57.985519           NaN     7
# 2     59.933083           NaN     7
# 3     43.117100           NaN     7
# 4     44.806789           NaN     7
# ...         ...           ...   ...
# 2217  44.986610  11430.177488     1
# 2218  44.988403  11431.631234     1
# 2219  44.985825  11435.714678     2
# 2220  44.985680  11442.261144     1
# 2221  44.988243  11443.982434     2
#
#                                                   kinds country
# 0                            accomodations,other_hotels  Россия
# 1                                 accomodations,resorts  Россия
# 2                    accomodations,hostels,guest_houses  Россия
# 3     architecture,historic_architecture,accomodatio...  Россия
# 4                            accomodations,other_hotels  Россия
# ...                                                 ...     ...
# 2217                         accomodations,other_hotels  Россия
# 2218                         guest_houses,accomodations  Россия
# 2219                         accomodations,other_hotels  Россия
# 2220                         accomodations,other_hotels  Россия
# 2221                         accomodations,other_hotels  Россия
#
# [1949 rows x 8 columns]

# %% [markdown]
# Рассмотрим столбец distance. Параметр distance указывает расстояние в метрах от выбранной точки во время запроса по радиусу. То есть нам известно расстояние части отелей от центра города. Это полезная характеристика и важный аспект при ценоформировании. Оставляем этот столбец. Однако стоит учитывать, что часть отелей были получены не методом radius, а с помощью bbox, поэтому множество строк оставлены с незаполненный параметром

# %%
opentripmap.isnull().sum()
# Out:
# id             0
# name           0
# longitude      0
# latitude       0
# distance     218
# rate           0
# kinds          0
# country        0
# dtype: int64

# %% [markdown]
# Заполняем незаполненные значения отрицательным числом -1

# %%
opentripmap['distance'] = opentripmap['distance'].fillna(-1)
opentripmap
# Out:
#            id                                              name   longitude  \
# 0     3818906                              Гостиница «Бристоль»   38.934727
# 1     3982337                     амакс курорт ""старая русса""   31.367519
# 2     3994795                                   порт на невском   30.353550
# 3     9522713                                       Тихий океан  131.879669
# 4     9595921  hotel metropol palace, a luxury collection hotel   20.473774
# ...       ...                                               ...         ...
# 2217  9580096                                        93hotel.ru   37.250084
# 2218  1770034                                           Ванатур   37.255215
# 2219  9580086                                       отель идеал   37.247829
# 2220  9580090                                            Кронос   37.247273
# 2221  1769972                           гостиница золотые пески   37.254368
#
#        latitude      distance  rate  \
# 0     47.211983     -1.000000     7
# 1     57.985519     -1.000000     7
# 2     59.933083     -1.000000     7
# 3     43.117100     -1.000000     7
# 4     44.806789     -1.000000     7
# ...         ...           ...   ...
# 2217  44.986610  11430.177488     1
# 2218  44.988403  11431.631234     1
# 2219  44.985825  11435.714678     2
# 2220  44.985680  11442.261144     1
# 2221  44.988243  11443.982434     2
#
#                                                   kinds country
# 0                            accomodations,other_hotels  Россия
# 1                                 accomodations,resorts  Россия
# 2                    accomodations,hostels,guest_houses  Россия
# 3     architecture,historic_architecture,accomodatio...  Россия
# 4                            accomodations,other_hotels  Россия
# ...                                                 ...     ...
# 2217                         accomodations,other_hotels  Россия
# 2218                         guest_houses,accomodations  Россия
# 2219                         accomodations,other_hotels  Россия
# 2220                         accomodations,other_hotels  Россия
# 2221                         accomodations,other_hotels  Россия
#
# [1949 rows x 8 columns]

# %%
opentripmap.to_csv('opentripmap_cleaned.csv', index=False)
opentripmap_cleaned = pd.read_csv("opentripmap_cleaned.csv")
# Out:
#            id                                              name   longitude  \
# 0     3818906                              Гостиница «Бристоль»   38.934727
# 1     3982337                     амакс курорт ""старая русса""   31.367519
# 2     3994795                                   порт на невском   30.353550
# 3     9522713                                       Тихий океан  131.879669
# 4     9595921  hotel metropol palace, a luxury collection hotel   20.473774
# ...       ...                                               ...         ...
# 1944  9580096                                        93hotel.ru   37.250084
# 1945  1770034                                           Ванатур   37.255215
# 1946  9580086                                       отель идеал   37.247829
# 1947  9580090                                            Кронос   37.247273
# 1948  1769972                           гостиница золотые пески   37.254368
#
#        latitude      distance  rate  \
# 0     47.211983     -1.000000     7
# 1     57.985519     -1.000000     7
# 2     59.933083     -1.000000     7
# 3     43.117100     -1.000000     7
# 4     44.806789     -1.000000     7
# ...         ...           ...   ...
# 1944  44.986610  11430.177488     1
# 1945  44.988403  11431.631234     1
# 1946  44.985825  11435.714678     2
# 1947  44.985680  11442.261144     1
# 1948  44.988243  11443.982434     2
#
#                                                   kinds country
# 0                            accomodations,other_hotels  Россия
# 1                                 accomodations,resorts  Россия
# 2                    accomodations,hostels,guest_houses  Россия
# 3     architecture,historic_architecture,accomodatio...  Россия
# 4                            accomodations,other_hotels  Россия
# ...                                                 ...     ...
# 1944                         accomodations,other_hotels  Россия
# 1945                         guest_houses,accomodations  Россия
# 1946                         accomodations,other_hotels  Россия
# 1947                         accomodations,other_hotels  Россия
# 1948                         accomodations,other_hotels  Россия
#
# [1949 rows x 8 columns]

# %%
opentripmap_cleaned
# Out:
#            id                                              name   longitude  \
# 0     3818906                              Гостиница «Бристоль»   38.934727
# 1     3982337                     амакс курорт ""старая русса""   31.367519
# 2     3994795                                   порт на невском   30.353550
# 3     9522713                                       Тихий океан  131.879669
# 4     9595921  hotel metropol palace, a luxury collection hotel   20.473774
# ...       ...                                               ...         ...
# 1944  9580096                                        93hotel.ru   37.250084
# 1945  1770034                                           Ванатур   37.255215
# 1946  9580086                                       отель идеал   37.247829
# 1947  9580090                                            Кронос   37.247273
# 1948  1769972                           гостиница золотые пески   37.254368
#
#        latitude      distance  rate  \
# 0     47.211983     -1.000000     7
# 1     57.985519     -1.000000     7
# 2     59.933083     -1.000000     7
# 3     43.117100     -1.000000     7
# 4     44.806789     -1.000000     7
# ...         ...           ...   ...
# 1944  44.986610  11430.177488     1
# 1945  44.988403  11431.631234     1
# 1946  44.985825  11435.714678     2
# 1947  44.985680  11442.261144     1
# 1948  44.988243  11443.982434     2
#
#                                                   kinds country
# 0                            accomodations,other_hotels  Россия
# 1                                 accomodations,resorts  Россия
# 2                    accomodations,hostels,guest_houses  Россия
# 3     architecture,historic_architecture,accomodatio...  Россия
# 4                            accomodations,other_hotels  Россия
# ...                                                 ...     ...
# 1944                         accomodations,other_hotels  Россия
# 1945                         guest_houses,accomodations  Россия
# 1946                         accomodations,other_hotels  Россия
# 1947                         accomodations,other_hotels  Россия
# 1948                         accomodations,other_hotels  Россия
#
# [1949 rows x 8 columns]
