# %% [markdown]
# # Использование API в открытом доступе. Hotellook
# Ссылка на сайт: https://search.hotellook.com/

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# Переходим на страницу [с отелями в Москве](https://search.hotellook.com/hotels?=1&cityId=12153), указываем любые параметры заселения. Изначально мы планировали получить информацию из сайта методом парсинга, однако после изучения исходного кода главной страницы и отдельной страницы для конкретного отеля было выявлено, что даже если на если выгруженных html можно получить информацию, то она не будет особо полезной, а затраты на парсинг плохо структурированных страниц будут крайне велики.
#
# После данного вывода, было решено рассмотреть внешние запросы, которые сайт делает во время загрузки. С помощью панели "Сеть" в инструментах разработчика браузера Microsoft Edge был найден интересный запрос на адрес https://search.hotellook.com/api/wl_search/result Название сайта сразу же привлекло наше внимание, поэтому мы решили скопировать запрос в виде curl (пример запроса смотри ниже), чтобы проверить, поможет ли данная находка в сборе информации.

# %% [markdown]
# ```bash
# curl 'https://search.hotellook.com/api/wl_search/result' \
#   -H 'accept: */*' \
#   -H 'accept-language: ru,en;q=0.9,en-GB;q=0.8,en-US;q=0.7' \
#   -H 'content-type: application/json' \
#   -b '_ym_uid=1740687636891539769; _ym_d=1740687636; _ym_isad=2; _fbp=fb.1.1740687635990.94303087349110335; _ym_visorc=w; locale=en; currency=RUB; _sp_ses.b93a=*; SERVERID=s1; hide_hotels=true; marker=direct.Zzf9414da07bac412a8081a93-126017; hotel_search_params=%7B%22params_attributes%22%3A%7B%22check_in%22%3A%222025-03-06%22%2C%22check_out%22%3A%222025-03-13%22%2C%22destination%22%3A%7B%22name%22%3A%22Moscow%22%2C%22location_id%22%3A12153%7D%7D%7D; __gads=ID=44dcaed736b18c79:T=1740690590:RT=1740690590:S=ALNI_MZXwNbPSlTOoNneAx98XOLGWMR8Tg; __gpi=UID=00001047f9069e5d:T=1740690590:RT=1740690590:S=ALNI_MavMYFmwoZLswhjRNWA5OEp3F6L2w; __eoi=ID=b27dad9016678eb9:T=1740690590:RT=1740690590:S=AA-AfjZC8WTywdSjZyrYKFv1Ea1G; _sp_id.b93a=0645083f-b576-46c5-ad0e-2bab35cc307c.1740687637.1.1740690593.1740687637.0c51d766-a433-4071-8ee4-45b25167c7f0' \
#   -H 'origin: https://search.hotellook.com' \
#   -H 'priority: u=1, i' \
#   -H 'referer: https://search.hotellook.com/hotels?=1&adults=2&checkIn=2025-03-06&checkOut=2025-03-13&children=&cityId=12153&currency=rub&destination=Moscow&language=en&marker=direct.Zzf9414da07bac412a8081a93-126017' \
#   -H 'sec-ch-ua: "Not(A:Brand";v="99", "Microsoft Edge";v="133", "Chromium";v="133"' \
#   -H 'sec-ch-ua-mobile: ?0' \
#   -H 'sec-ch-ua-platform: "Windows"' \
#   -H 'sec-fetch-dest: empty' \
#   -H 'sec-fetch-mode: cors' \
#   -H 'sec-fetch-site: same-origin' \
#   -H 'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0' \
#   --data-raw '{"page":"serp","search_id":"23882775-d9cb-466e-8077-68984e8b2c3f","params":{"check_in":"2025-03-06","check_out":"2025-03-13","marker":"direct.Zzf9414da07bac412a8081a93-126017","currency":"rub","locale":"en","rooms":[{"adults":2,"children":[]}],"locations_ids":[12153],"hotels_ids":[],"destination":"Moscow","host":"search.hotellook.com","flags":{"auid":null,"ab":null,"deviceType":"mobile"},"popularity":"default"},"selected_hotels_ids":[],"filters":{"prices":{"groups":[0,500,1000,1500,2000,2500,3000,4000,5000,6000,7000,8000,9000,12000,15000,20000,30000,50000,100000,2147483647]},"ratings":{"groups":[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10]}},"sort":"popularity","limit":10,"offset":0}'
# ```

# %% [markdown]
# Помимо самого запроса и сопровождающих заголовков можно заметить "сырые данные" data-raw, это параметры запроса к API hotellook. Параметры указаны в виде JSON-данных. Мы можем воссоздать такой же запрос с помощью питона, используя библиотеку requests. Заодно уберем лишние заголовки и параметры, без которых ответ запрос не изменится

# %%
def get_all_hotellook_data(limit, location_id=[12153]):
    url = "https://search.hotellook.com/api/wl_search/result"
    
    headers = {
        "accept": "*/*",
        "accept-language": "ru,en;q=0.9,en-GB;q=0.8,en-US;q=0.7",
        "content-type": "application/json",
        "origin": "https://search.hotellook.com",
        "priority": "u=1, i",
        "referer": f"https://search.hotellook.com/hotels?=1&cityId={location_id}",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0"
    }
    
    payload = {
        "page": "serp",
        "search_id": "",
        "params": {
            "check_in": "2025-02-28",
            "check_out": "2025-03-01",
            "currency": "rub",
            "locale": "ru",
            "rooms": [{"adults": 2, "children": []}],
            "locations_ids": location_id,
            "destination": None,
            "hotels_ids": [],
            "host": "search.hotellook.com",
            "flags": {"auid": None, "ab": None, "deviceType": "mobile"},
            "popularity": "default"
        },
        "sort": "popularity",
        "limit": limit,
        "offset": 0
    }
    
    response = requests.post(url, headers=headers, json=payload)
    
    if response.status_code == 200:
        data = response.json()
        with open(f"hotellook_alldata_limit-{limit}.json", "w", encoding="utf-8") as file:
            json.dump(data, file, ensure_ascii=False, indent=4)
            print(f"Данные загружены в hotellook.json. Число запросов: {limit}")
    else:
        print(f"Ошибка {response.status_code}: {response.text}")
    return

# %%
get_all_hotellook_data(10)
# Out:
# Данные загружены в hotellook.json. Число запросов: 10

# %% [markdown]
# В данном response есть полезные данные, которые затем будут использованы в проекте. Напишем функцию, которая будет обрабатывать полученный json и отбирать всю возможную информацию о каждом отеле.

# %%
def extract_full_hotel_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    hotels = data.get("hotels", [])

    full_hotel_data = []
    for hotel in hotels:
        hotel_info = {
            "id": hotel.get("id"),
            "name": hotel.get("name"),
            "address": hotel.get("address"),
            "location_id": hotel.get("location_id"),
            "latitude": hotel.get("location", {}).get("lat"),
            "longitude": hotel.get("location", {}).get("lon"),
            "stars": hotel.get("stars"),
            "rating": hotel.get("rating"),
            "reviews_count": hotel.get("reviews_count"),
            "min_price": hotel.get("minprice"),
            "median_min_price": hotel.get("median_minprice"),
            "distance_to_center": hotel.get("distance_to_center"),
            "chain": hotel.get("chain"),
            "property_type": hotel.get("property_type"),
            "photos_count": hotel.get("photos_count"),
            "amenities": hotel.get("amenities"),
            "badges": [badge["code"] for badge in (hotel.get("badges") or {}).get("badges", [])],
            "check_in": hotel.get("check_in"),
            "check_out": hotel.get("check_out"),
            "year_opened": hotel.get("year_opened"),
            "year_renovated": hotel.get("year_renovated"),
            "popularity": hotel.get("popularity"),
            "popularity2": hotel.get("popularity2"),
            "trending_speed": hotel.get("trending_speed"),
            "photos_ids": hotel.get("photos_ids"),
            "pois_distances": hotel.get("pois_distances"),
            "nearest_poi_by_category": hotel.get("nearest_poi_by_category"),
            "districts_ids": hotel.get("districts_ids"),
            "weights": hotel.get("weights"),
            "scoring": hotel.get("scoring"),
            "debug_info": hotel.get("debug_info"),
        }
        full_hotel_data.append(hotel_info)

    return pd.DataFrame(full_hotel_data)

# %%
file_path = "hotellook_alldata_limit-10.json"
df_full_hotels = extract_full_hotel_data(file_path)
df_full_hotels
# Out:
#            id                                     name  \
# 0      333570                     Отель Вега Измайлово
# 1     1198039             Sunflower Авеню Отель Москва
# 2      333559            Холидей Инн Москва Сокольники
# 3  1704466136  Хилтон Гарден Инн Москва Красносельская
# 4      333572                           Отель Бородино
# 5    44463003                       ibis Москва Динамо
# 6  1899369125                    Арт Москва Войковская
# 7      276236                Гостиница Альфа Измайлово
# 8      276243                     Москоу Холидэй Отель
# 9  1898005746                         Покровка 6 Отель
#
#                                address  location_id   latitude  longitude  \
# 0    Измайловское шоссе 71 строение 3В        12153  55.790752  37.747135
# 1                Ул. Щепкина 32, стр.1        12153  55.779600  37.629820
# 2                    Русаковская ул.24        12153  55.787690  37.680330
# 3  Улица Верхняя Красносельская, 11а-4        12153  55.784810  37.662830
# 4                  Русаковская ул.13/5        12153  55.784580  37.672400
# 5  Ленинградский Проспект 37, корпус 8        12153  55.792400  37.543470
# 6         Ulitsa Kosmonavta Volkova 6А        12153  55.815300  37.512740
# 7       Измайловское шоссе 71 корпус А        12153  55.789787  37.749550
# 8            Улица Мневники, 3, стр. 2        12153  55.773730  37.499120
# 9         улица Покровка, д. 6, Москва        12153  55.758730  37.642040
#
#    stars  rating  reviews_count  min_price  ...  popularity  popularity2  \
# 0      4     9.0          15712         46  ...       16804         2268
# 1      3     8.9           3195         35  ...       16803         1399
# 2      4     9.0           9624         53  ...       16802         1855
# 3      4     9.1           4499         55  ...       16801          486
# 4      4     8.9           4871         47  ...       16800          918
# 5      3     8.7           6839         39  ...       16799         1215
# 6      4     8.8           2343         42  ...       16798          728
# 7      4     8.6          18605         38  ...       16797         2567
# 8      4     8.3           3282         33  ...       16796          413
# 9      3     9.6              0         38  ...       16795          326
#
#   trending_speed                                         photos_ids  \
# 0           0.00  [7489913361, 8352837505, 8352837517, 748991281...
# 1           0.89  [8693498484, 8693498482, 8693498477, 869349848...
# 2           0.18  [7972531316, 7949733813, 7862423210, 791411950...
# 3           0.69  [8725235261, 8725235254, 8725235256, 872523524...
# 4           0.39  [7761510695, 7504780382, 7760836716, 750478632...
# 5           0.25  [7630677409, 8793151888, 8863392105, 886339209...
# 6           2.78  [9525299954, 9525299955, 9525299950, 952529994...
# 7           0.00  [7487223299, 7761608657, 7761609184, 776160902...
# 8           1.59  [7499262649, 7499265095, 7925002564, 749926063...
# 9           0.00  [8734876847, 8734876854, 8734876866, 873487685...
#
#                                       pois_distances  \
# 0  {'69873': 35331, '69874': 42911, '69885': 2839...
# 1  {'69873': 28861, '69874': 43984, '69885': 2465...
# 2  {'69873': 31827, '69874': 43714, '69885': 2579...
# 3  {'69873': 30787, '69874': 43771, '69885': 2536...
# 4  {'69873': 31225, '69874': 43546, '69885': 2575...
# 5  {'69873': 26286, '69874': 47594, '69885': 2089...
# 6  {'69873': 27341, '69874': 50748, '69885': 1783...
# 7  {'69873': 35390, '69874': 42772, '69885': 2857...
# 8  {'69873': 22981, '69874': 47199, '69885': 2202...
# 9  {'69873': 27938, '69874': 41548, '69885': 2703...
#
#                              nearest_poi_by_category       districts_ids  \
# 0  {'airport': 69885, 'metro_station': 72010, 'tr...           [1416636]
# 1  {'airport': 69885, 'metro_station': 71913, 'tr...  [1667834, 1676723]
# 2  {'airport': 69885, 'metro_station': 72006, 'tr...           [1416636]
# 3  {'airport': 69885, 'metro_station': 71908, 'tr...  [1667837, 1676723]
# 4  {'airport': 69885, 'metro_station': 71908, 'tr...  [1667837, 1676723]
# 5  {'airport': 69885, 'beach': 323310, 'metro_sta...           [1467379]
# 6  {'airport': 69885, 'beach': 323310, 'metro_sta...           [1467379]
# 7  {'airport': 69885, 'metro_station': 72010, 'tr...           [1416636]
# 8         {'airport': 69885, 'metro_station': 71872}           [1667879]
# 9  {'airport': 69885, 'metro_station': 71875, 'tr...  [1667836, 1676723]
#
#                   weights scoring  debug_info
# 0  {'default': 2.2766292}      {}
# 1  {'default': 2.2280583}      {}
# 2  {'default': 2.2625914}      {}
# 3  {'default': 2.2162018}      {}
# 4   {'default': 2.212328}      {}
# 5   {'default': 2.172786}      {}
# 6  {'default': 2.1888375}      {}
# 7   {'default': 2.195934}      {}
# 8  {'default': 2.1297414}      {}
# 9  {'default': 2.1378424}      {}
#
# [10 rows x 31 columns]

# %% [markdown]
# У нас получилось загрузить в датасет первые данные в их изначальном формате - отбором полезных столбцов и преобразованием займемся позже на этапе EDA. Сейчас нам необходимо выгрузить все возможные данные

# %% [markdown]
# Перед этим убедимся, что запрос ко всем отелям в городе и запрос к конкретному отелю не различается в объеме предоставляемой информации. Создадим функцию, которая делает запрос только к одному отеля, повторив все ранее описанные действия - зайдем на страницу отеля, подсмотрим и честно воспользуемся найденным запросом к API, перепишем все на питон и сохраним результат.

# %%
def get_single_hotel_data(hotel_id):
    url = "https://search.hotellook.com/api/wl_search/result"
    
    headers = {
        "accept": "*/*",
        "accept-language": "ru,en;q=0.9,en-GB;q=0.8,en-US;q=0.7",
        "content-type": "application/json",
        "origin": "https://search.hotellook.com",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0"
    }
    
    payload = {
        "page": "hotel_page",
        "search_id": "7c33f3c5-37ab-4ead-88c4-84c31e121e33",
        "params": {
            "marker": "direct.Zz1f6b911e8a60403ca251d64-126017",
            "currency": "rub",
            "locale": "ru",
            "locations_ids": [],
            "hotels_ids": [hotel_id],
            "host": "search.hotellook.com",
            "flags": {"auid": None, "ab": None, "deviceType": "desktop"},
            "popularity": "default"
        },
        "selected_hotels_ids": [],
        "filters": {},
        "sort": "popularity",
        "limit": 1,
        "offset": 0
    }
    
    response = requests.post(url, headers=headers, json=payload)
    
    if response.status_code == 200:
        data = response.json()
        with open(f"hotellook_single_{hotel_id}.json", "w", encoding="utf-8") as file:
            json.dump(data, file, ensure_ascii=False, indent=4)
        return data
    else:
        print(f"Ошибка {response.status_code}: {response.text}")
        return None

get_single_hotel_data(1198039)
# Out:
# {'search_id': '',
#  'stop': True,
#  'locations': {'12196': {'seasons': {},
#    'name': 'Санкт-Петербург',
#    'country_name': 'Россия',
#    'country_id': 186,
#    'declensions': {'1': 'Санкт-Петербург',
#     '2': 'Санкт-Петербурга',
#     '3': 'Санкт-Петербургу',
#     '4': 'Санкт-Петербург',
#     '5': 'Санкт-Петербургом',
#     '6': 'Санкт-Петербургe',
#     '7': 'в Санкт-Петербурге'},
#    'property_types_count': {'by_types': {'0': 58,
#      '1': 729,
#      '2': 40,
#      '3': 11,
#      '4': 2656,
#      '5': 2,
#      '6': 113,
#      '7': 94,
#      '8': 6},
#     'total': 3709},
#    'timezone': 'Europe/Moscow',
#    'iatas': [],
#    'center_coords': {'lat': 59.95, 'lon': 30.316668},
#    'full_name': 'Санкт-Петербург, Россия',
#    'pois_ids': [],
#    'latin_name': 'St. Petersburg',
#    'latin_country_name': 'Russia',
#    'id': 12196,
#    'zones': ['eurasia', 'asia', 'europe'],
#    'state_code': '',
#    'code': 'LED',
#    'country_code': 'RU',
#    'latin_full_name': 'St. Petersburg, Russia',
#    'path': '186.1416746.12196',
#    'parents_names': 'Россия',
#    'type': 'City'}},
#  'districts': {'1416598': {'name': 'Адмиралтейский район',
#    'id': 1416598,
#    'path': '186.1416746.12196.1416598'}},
#  'filters': {'counters': {'prices': None,
#    'property_types': {},
#    'stars': {},
#    'hotels_amenities': {},
#    'districts': {},
#    'ratings': None,
#    'distance_to_center': None,
#    'proposals_options': {},
#    'distance_to': {},
#    'agencies': {}}},
#  'hotels_amenities': {'1': {'slug': 'parking',
#    'name': 'Парковка',
#    'category': 'hotel'},
#   '4': {'slug': 'tv', 'name': 'Телевизор', 'category': 'room'},
#   '5': {'slug': 'laundry', 'name': 'Прачечная', 'category': 'hotel'},
#   '10': {'slug': 'wi-fi in public areas',
#    'name': 'Wi-Fi в лобби',
#    'category': 'hotel'},
#   '11': {'slug': 'wi-fi in room',
#    'name': 'Wi-fi в комнатах',
#    'category': 'room'},
#   '12': {'slug': 'hairdryer', 'name': 'Фен', 'category': 'room'},
#   '13': {'slug': 'shared bathroom',
#    'name': 'Общая ванная',
#    'category': 'room'},
#   '14': {'slug': 'safe', 'name': 'Сейф', 'category': 'room'},
#   '18': {'slug': '24h. reception',
#    'name': 'Ресепшн 24 часа',
#    'category': 'hotel'},
#   '22': {'slug': 'dormitory', 'name': 'Общие номера', 'category': 'room'}},
#  'total_hotels': 0,
#  'filtered_hotels': 0,
#  'hotels': [{'room_count': 19,
#    'check_in': '15:00',
#    'check_out': '12:00',
#    'distance_to_center': 2004,
#    'address': 'Набережная реки Мойки 62/2 кв 9',
#    'name': 'Soul Kitchen Hostel',
#    'location_id': 12196,
#    'photos_ids': ['9592366464',
#     '8362574886',
#     '9710348061',
#     '9710348065',
#     '9710348056',
#     '9710348058',
#     '9710348064',
#     '9592366537',
#     '8846987904',
#     '9592366523',
#     '9533485192',
#     '9592366506',
#     '9533485219',
#     '9592366498',
#     '9533485191',
#     '9592366515',
#     '9592366527',
#     '9592366528',
#     '9592366547',
#     '9592366548',
#     '9592366551',
#     '9592366553',
#     '9738837744',
#     '9738837745'],
#    'minprice': 32,
#    'property_type': 'HOSTEL',
#    'rating': 9.7,
#    'stars': 0,
#    'year_opened': 2012,
#    'year_renovated': 0,
#    'locations_ids': [12196],
#    'popularity2': 93,
#    'locations_distances': {'12196': 2004},
#    'reviews_count': 1671,
#    'pois_distances': {'71006': 14016,
#     '71842': 706,
#     '71862': 734,
#     '71886': 717,
#     '71899': 880,
#     '72040': 440,
#     '314155': 3579,
#     '314156': 2709,
#     '314157': 2888,
#     '346587': 1742},
#    'description': "Location Soul Kitchen Living quarters located in the center of St. Petersburg. The living quarters is located between the historical district of Kolomna and the main attractions of the city. Nearby is St. Isaac's Cathedral, within walking distance of Nevsky Prospekt, Kazan Cathedral and Palace Square, as well as the Mariinsky Theater, New Holland Island, Yusupov Palace.At the living quarters In addition to private rooms, the living quarters have common spaces - a fully equipped kitchen with necessary utensils and a common living room with a projector for watching movies.",
#    'location': {'lat': 59.93212, 'lon': 30.31268},
#    'photos_by_room_type': {'1': {'photos_ids': ['9592366537',
#       '9592366506',
#       '9592366515',
#       '9592366527',
#       '9592366528',
#       '9592366547',
#       '9592366548',
#       '9592366566',
#       '9592366526',
#       '9533485202',
#       '9533485206',
#       '9533485208',
#       '9533485213',
#       '9533485216',
#       '9592366478',
#       '9592366502',
#       '9592366504',
#       '9592366505',
#       '9592366512',
#       '9592366532',
#       '9592366533',
#       '9592366534',
#       '9592366535',
#       '9592366536',
#       '9592366539',
#       '9592366540',
#       '9592366541',
#       '9592366549',
#       '9592366554',
#       '9592366555',
#       '9592366556',
#       '9592366557',
#       '9592366558',
#       '9592366559',
#       '9592366560',
#       '9592366561',
#       '9592366562',
#       '9592366563',
#       '9592366564',
#       '9592366565',
#       '9592366567',
#       '9592366568',
#       '9592366569',
#       '9592366525',
#       '9592366524'],
#      'count': 0},
#     '2': {'photos_ids': ['9592366506',
#       '9592366566',
#       '9533485206',
#       '9533485216',
#       '9592366478',
#       '9592366502',
#       '9592366505',
#       '9592366512',
#       '9592366554',
#       '9592366555',
#       '9592366556',
#       '9592366557',
#       '9592366558',
#       '9592366559',
#       '9592366560',
#       '9592366561',
#       '9592366562',
#       '9592366563',
#       '9592366564',
#       '9592366565',
#       '9592366567',
#       '9592366568',
#       '9592366569'],
#      'count': 0},
#     '12': {'photos_ids': ['9533485219',
#       '9592366498',
#       '9592366501',
#       '9533485205',
#       '9533485207',
#       '9592366538',
#       '9592366542',
#       '9592366543',
#       '9592366544',
#       '9592366545',
#       '9592366546'],
#      'count': 0},
#     '13': {'photos_ids': ['9592366503',
#       '9592366572',
#       '9592366574',
#       '9592366575',
#       '9592366577',
#       '9592366578',
#       '9592366579'],
#      'count': 0},
#     '31': {'photos_ids': ['9592366551',
#       '9592366553',
#       '9592366529',
#       '9533485193',
#       '9533485210',
#       '9533485211',
#       '9533485212',
#       '9533485214',
#       '9533485215',
#       '9533485217',
#       '9592366494',
#       '9592366495',
#       '9592366496',
#       '9592366499',
#       '9592366500',
#       '9592366510',
#       '9592366511',
#       '9592366530',
#       '9592366531',
#       '9592366550',
#       '9592366552',
#       '9592366570',
#       '9592366571',
#       '9592366573',
#       '9592366576',
#       '9592366580',
#       '9592366508'],
#      'count': 0}},
#    'districts_ids': [1416598],
#    'chain': '',
#    'scoring': {},
#    'id': 714765,
#    'popularity': 506882,
#    'amenitiesv2': {'categories': {'hotel': {'values': [{'slug': 'wi-fi_in_public_areas',
#         'price': 'free',
#         'name': 'Wi-Fi в лобби'},
#        {'slug': 'parking', 'price': 'free', 'name': 'Парковка'},
#        {'slug': '24_hours_front_desk_service',
#         'price': '',
#         'name': 'Ресепшн 24 часа'},
#        {'slug': 'laundry_service', 'price': '', 'name': 'Прачечная'}]},
#      'language': {'values': [{'slug': 'english',
#         'price': '',
#         'name': 'Английский'},
#        {'slug': 'russian', 'price': '', 'name': 'Русский'}]},
#      'room': {'values': [{'slug': 'wi-fi_in_rooms',
#         'price': 'free',
#         'name': 'Wi-fi в комнатах'},
#        {'slug': 'tv', 'price': '', 'name': 'Телевизор'},
#        {'slug': 'safe_box', 'price': '', 'name': 'Сейф'},
#        {'slug': 'hairdryer', 'price': '', 'name': 'Фен'},
#        {'slug': 'shared_bathroom', 'price': '', 'name': 'Общая ванная'},
#        {'slug': 'dormitory', 'price': '', 'name': 'Общие номера'}]}}},
#    'latin_name': 'Soul Kitchen Hostel',
#    'is_rentals': False,
#    'has_rentals': True,
#    'photos_count': 24,
#    'latin_full_name': '',
#    'full_name': '',
#    'property_type_id': 7,
#    'amenities': [11, 12, 14, 18, 22, 1, 4, 5, 10, 13],
#    'badges': {'badges': [{'show_on_search_card': True,
#       'code': 'stylish',
#       'popularity': 0},
#      {'show_on_search_card': False, 'code': 'designer', 'popularity': 0},
#      {'show_on_search_card': False, 'code': 'friendly', 'popularity': 0},
#      {'show_on_search_card': False, 'code': 'kitchenette', 'popularity': 0}]},
#    'weights': {},
#    'nearest_poi_by_category': {'airport': 71006,
#     'beach': 346587,
#     'metro_station': 72040,
#     'train_station': 314156},
#    'address_parent_ids': [1416598, 12196, 1416746, 186],
#    'price_group': 2,
#    'median_minprice': 56,
#    'readable_reviews_count': 0,
#    'rating_reviews_count': 1671,
#    'best_photo_weight': 0,
#    'trending_speed': 0,
#    'debug_info': ''}],
#  'proposals': {},
#  'property_types': {'7': 'Хостел'},
#  'gates': {},
#  'proposals_options': {},
#  'hotels_map': {},
#  'trustyou': {'714765': {'good_to_know': [{'count': 0.0347,
#      'ratio': 'Good',
#      'score': 100,
#      'review_count': 58,
#      'category_name': 'Дизайнерская обстановка',
#      'text': 'Стильный хостел',
#      'relevance': 5.370795,
#      'sentiment': 'pos',
#      'short_text': 'Стильный хостел',
#      'category_id': 'vdes',
#      'highlight_list': [{'text': 'Приятный дизайн',
#        'confidence': 100,
#        'category_id_list': ['244', 'vdes', '171'],
#        'sentiment': ''}]},
#     {'count': 0.0497,
#      'ratio': 'Good',
#      'score': 100,
#      'review_count': 83,
#      'category_name': 'Кухня',
#      'text': 'Хорошая мини-кухня',
#      'relevance': 3.8762882,
#      'sentiment': 'pos',
#      'short_text': 'Хорошая мини-кухня',
#      'category_id': '11j',
#      'highlight_list': [{'text': 'Неплохая кухня',
#        'confidence': 100,
#        'category_id_list': ['11', '11j'],
#        'sentiment': ''},
#       {'text': 'Хорошая кухня',
#        'confidence': 100,
#        'category_id_list': ['11', '11j'],
#        'sentiment': ''}]},
#     {'count': 0.0874,
#      'ratio': 'Good',
#      'score': 99,
#      'review_count': 146,
#      'category_name': 'Дружелюбная атмосфера',
#      'text': 'Дружественная атмосфера',
#      'relevance': 3.205632,
#      'sentiment': 'pos',
#      'short_text': 'Дружественная атмосфера',
#      'category_id': '9ba9',
#      'highlight_list': [{'text': 'Домашняя обстановка',
#        'confidence': 100,
#        'category_id_list': ['9ba9', '171'],
#        'sentiment': ''},
#       {'text': 'Обстановка домашняя',
#        'confidence': 100,
#        'category_id_list': ['9ba9', '171'],
#        'sentiment': ''},
#       {'text': 'Уютная обстановка',
#        'confidence': 100,
#        'category_id_list': ['9ba9', '171'],
#        'sentiment': ''}]},
#     {'count': 0.0497,
#      'ratio': 'Good',
#      'score': 82,
#      'review_count': 83,
#      'category_name': 'Ванная комната',
#      'text': 'Впечатляющий санузел',
#      'relevance': 1.1851938,
#      'sentiment': 'pos',
#      'short_text': 'Впечатляющий санузел',
#      'category_id': '11a',
#      'highlight_list': [{'text': 'Большие полотенца',
#        'confidence': 100,
#        'category_id_list': ['11', '111', '11a', '5b6c', '4b72'],
#        'sentiment': ''},
#       {'text': 'Душевых много',
#        'confidence': 100,
#        'category_id_list': ['11m', '11', '11a'],
#        'sentiment': ''},
#       {'text': 'Превосходный санузел',
#        'confidence': 100,
#        'category_id_list': ['11', '11a'],
#        'sentiment': ''}]}],
#    'sentiment_score_list': [{'count': 0.1329,
#      'ratio': 'Good',
#      'score': 99,
#      'review_count': 222,
#      'category_name': 'Атмосфера',
#      'text': 'Отличная атмосфера.',
#      'relevance': 1.7003353,
#      'sentiment': 'pos',
#      'short_text': 'Великолепная атмосфера',
#      'category_id': '171',
#      'highlight_list': [{'text': 'Домашняя обстановка',
#        'confidence': 100,
#        'category_id_list': ['9ba9', '171'],
#        'sentiment': ''},
#       {'text': 'Обстановка домашняя',
#        'confidence': 100,
#        'category_id_list': ['9ba9', '171'],
#        'sentiment': ''},
#       {'text': 'Уютная обстановка',
#        'confidence': 100,
#        'category_id_list': ['9ba9', '171'],
#        'sentiment': ''}],
#      'sub_category_list': [{'count': 0.0874,
#        'ratio': '',
#        'score': 99,
#        'review_count': 146,
#        'category_name': 'Дружелюбная атмосфера',
#        'text': '99% в восторге от дружественной атмосферы.',
#        'relevance': 3.205632,
#        'sentiment': 'pos',
#        'short_text': 'Дружественная атмосфера',
#        'category_id': '9ba9',
#        'highlight_list': [{'text': 'Домашняя обстановка',
#          'confidence': 100,
#          'category_id_list': ['9ba9', '171'],
#          'sentiment': ''},
#         {'text': 'Обстановка домашняя',
#          'confidence': 100,
#          'category_id_list': ['9ba9', '171'],
#          'sentiment': ''},
#         {'text': 'Уютная обстановка',
#          'confidence': 100,
#          'category_id_list': ['9ba9', '171'],
#          'sentiment': ''}]},
#       {'count': 0.0347,
#        'ratio': '',
#        'score': 100,
#        'review_count': 58,
#        'category_name': 'Дизайнерская обстановка',
#        'text': '100% отметили, что это стильный хостел.',
#        'relevance': 5.370795,
#        'sentiment': 'pos',
#        'short_text': 'Стильный хостел',
#        'category_id': 'vdes',
#        'highlight_list': [{'text': 'Приятный дизайн',
#          'confidence': 100,
#          'category_id_list': ['244', 'vdes', '171'],
#          'sentiment': ''}]},
#       {'count': 0.0078,
#        'ratio': '',
#        'score': 85,
#        'review_count': 13,
#        'category_name': 'Входной холл',
#        'text': '85% в восторге от вестибюля.',
#        'relevance': 1.11434,
#        'sentiment': 'pos',
#        'short_text': 'Прекрасный вестибюль',
#        'category_id': '24b',
#        'highlight_list': []},
#       {'count': 0.009,
#        'ratio': '',
#        'score': 95,
#        'review_count': 15,
#        'category_name': 'Современная обстановка',
#        'text': '95% отметили, что хостел современный.',
#        'relevance': 1.2722458,
#        'sentiment': 'pos',
#        'short_text': 'Современный хостел',
#        'category_id': 'vmod',
#        'highlight_list': [{'text': 'Новое пастельное белье',
#          'confidence': 100,
#          'category_id_list': ['11', 'ae0f', 'vmod', '11b', '111', '171'],
#          'sentiment': ''}]}],
#      'summary_sentence_list': [{'text': 'Великолепная атмосфера.',
#        'confidence': 0,
#        'category_id_list': ['171'],
#        'sentiment': 'pos'},
#       {'text': 'Дружественная атмосфера.',
#        'confidence': 0,
#        'category_id_list': ['9ba9'],
#        'sentiment': 'pos'},
#       {'text': 'Стильный хостел.',
#        'confidence': 0,
#        'category_id_list': ['vdes'],
#        'sentiment': 'pos'},
#       {'text': 'Прекрасный вестибюль.',
#        'confidence': 0,
#        'category_id_list': ['24b'],
#        'sentiment': 'pos'},
#       {'text': 'Современный хостел.',
#        'confidence': 0,
#        'category_id_list': ['vmod'],
#        'sentiment': 'pos'},
#       {'text': 'Подходит для индивидуальных путешественников.',
#        'confidence': 0,
#        'category_id_list': ['16u'],
#        'sentiment': 'pos'},
#       {'text': 'Хорошо подходит для путешествий с компанией друзей.',
#        'confidence': 0,
#        'category_id_list': ['16ag'],
#        'sentiment': 'pos'},
#       {'text': 'Приятный хостел.',
#        'confidence': 0,
#        'category_id_list': ['16ae'],
#        'sentiment': 'pos'}]},
#     {'count': 0.1885,
#      'ratio': 'Good',
#      'score': 99,
#      'review_count': 315,
#      'category_name': 'Расположение',
#      'text': 'Превосходное расположение.',
#      'relevance': 1,
#      'sentiment': 'pos',
#      'short_text': 'Отличное\xa0расположение',
#      'category_id': '14',
#      'highlight_list': [{'text': 'Отличное месторасположение',
#        'confidence': 100,
#        'category_id_list': ['14'],
#        'sentiment': ''},
#       {'text': 'Отличное местоположение',
#        'confidence': 100,
#        'category_id_list': ['14'],
#        'sentiment': ''},
#       {'text': 'Шикарная столовая',
#        'confidence': 100,
#        'category_id_list': ['14'],
#        'sentiment': ''}],
#      'sub_category_list': [{'count': 0.0036,
#        'ratio': '',
#        'score': 100,
#        'review_count': 6,
#        'category_name': 'Рестораны и бары',
#        'text': '100% понравились рестораны и бары в округе.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Активная ночная жизнь',
#        'category_id': '14d',
#        'highlight_list': []},
#       {'count': 0.0048,
#        'ratio': '',
#        'score': 100,
#        'review_count': 8,
#        'category_name': 'Удаленность от центра города',
#        'text': 'До центра города добираться удобно, отметили 100%.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Центр города рядом',
#        'category_id': '14h',
#        'highlight_list': []},
#       {'count': 0.0036,
#        'ratio': '',
#        'score': 100,
#        'review_count': 6,
#        'category_name': 'Удаленность от общественного транспорта',
#        'text': 'Удобно добираться на общественном транспорте, по мнению 100%.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Удобно добираться на общественном транспорте',
#        'category_id': '14i',
#        'highlight_list': [{'text': 'Метро в шаговой доступности',
#          'confidence': 100,
#          'category_id_list': ['14', '14i'],
#          'sentiment': ''}]}],
#      'summary_sentence_list': [{'text': 'Хорошее расположение, рядом с остановками общественного транспорта.',
#        'confidence': 0,
#        'category_id_list': ['14i', '14'],
#        'sentiment': 'pos'},
#       {'text': 'Рядом с центром города и отличными ночными заведениями.',
#        'confidence': 0,
#        'category_id_list': ['14d', '14h'],
#        'sentiment': 'pos'}]},
#     {'count': 0.0616,
#      'ratio': 'Good',
#      'score': 98,
#      'review_count': 103,
#      'category_name': 'Еда',
#      'text': 'Еда – пальчики оближешь.',
#      'relevance': 1.0920618,
#      'sentiment': 'pos',
#      'short_text': 'Отличная еда',
#      'category_id': '13',
#      'highlight_list': [{'text': 'Вкусно готовят',
#        'confidence': 100,
#        'category_id_list': ['13'],
#        'sentiment': ''},
#       {'text': 'Большая кухня',
#        'confidence': 100,
#        'category_id_list': ['13'],
#        'sentiment': ''},
#       {'text': 'Вкусные пироги',
#        'confidence': 100,
#        'category_id_list': ['13'],
#        'sentiment': ''}],
#      'sub_category_list': [{'count': 0.0132,
#        'ratio': '',
#        'score': 100,
#        'review_count': 22,
#        'category_name': 'Стоимость Еды',
#        'text': '100% порадовались ценам.',
#        'relevance': 2.8102946,
#        'sentiment': 'pos',
#        'short_text': 'Доступное питание',
#        'category_id': '2dca',
#        'highlight_list': [{'text': 'Бесплатную чашку',
#          'confidence': 100,
#          'category_id_list': ['2dca', '13', '22a'],
#          'sentiment': ''}]},
#       {'count': 0.0066,
#        'ratio': '',
#        'score': 100,
#        'review_count': 11,
#        'category_name': 'Впечатления от питания',
#        'text': '100% понравились обеды.',
#        'relevance': 1.0488479,
#        'sentiment': 'pos',
#        'short_text': 'Отличные цены на обеды',
#        'category_id': 'ef97',
#        'highlight_list': [{'text': 'Чистой кухней',
#          'confidence': 100,
#          'category_id_list': ['2b39', '13', 'ef97', '333'],
#          'sentiment': ''}]}],
#      'summary_sentence_list': [{'text': 'Прекрасное впечатление от питания, невысокие цены.',
#        'confidence': 0,
#        'category_id_list': ['2dca', 'ef97', '13'],
#        'sentiment': 'pos'}]},
#     {'count': 0.0886,
#      'ratio': 'Good',
#      'score': 97,
#      'review_count': 148,
#      'category_name': 'Чистота',
#      'text': 'Идеально чисто.',
#      'relevance': 1.0267631,
#      'sentiment': 'pos',
#      'short_text': 'Довольно чисто',
#      'category_id': '333',
#      'highlight_list': [{'text': 'Чистой кухней',
#        'confidence': 100,
#        'category_id_list': ['2b39', '13', 'ef97', '333'],
#        'sentiment': ''},
#       {'text': 'Идеальная чистота',
#        'confidence': 100,
#        'category_id_list': ['333'],
#        'sentiment': ''},
#       {'text': 'Номера чистые',
#        'confidence': 100,
#        'category_id_list': ['11', 'f63a', '333'],
#        'sentiment': ''}],
#      'sub_category_list': [{'count': 0.0431,
#        'ratio': '',
#        'score': 97,
#        'review_count': 72,
#        'category_name': 'Чистота в номере',
#        'text': '97% отметили, что номера чистые.',
#        'relevance': 1.0230029,
#        'sentiment': 'pos',
#        'short_text': 'Чистые номера',
#        'category_id': 'f63a',
#        'highlight_list': [{'text': 'Номера чистые',
#          'confidence': 100,
#          'category_id_list': ['11', 'f63a', '333'],
#          'sentiment': ''},
#         {'text': 'Чистейшие номера',
#          'confidence': 100,
#          'category_id_list': ['f63a', '11', '333'],
#          'sentiment': ''},
#         {'text': 'Чистый санузел',
#          'confidence': 100,
#          'category_id_list': ['11', 'f63a', '343c', '11a', '333'],
#          'sentiment': ''}]},
#       {'count': 0.0413,
#        'ratio': '',
#        'score': 97,
#        'review_count': 69,
#        'category_name': 'Чистота в отеле',
#        'text': '97% отметили, что в хостеле чисто.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'В хостеле чисто',
#        'category_id': '9f14',
#        'highlight_list': [{'text': 'Чистые помещения',
#          'confidence': 100,
#          'category_id_list': ['244', '9f14', '333'],
#          'sentiment': ''}]},
#       {'count': 0.0132,
#        'ratio': '',
#        'score': 90,
#        'review_count': 22,
#        'category_name': 'Чистота ванной комнаты',
#        'text': '90% отметили, что санузел чистый.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Чистый санузел',
#        'category_id': '343c',
#        'highlight_list': [{'text': 'Чистый санузел',
#          'confidence': 100,
#          'category_id_list': ['11', 'f63a', '343c', '11a', '333'],
#          'sentiment': ''}]}],
#      'summary_sentence_list': [{'text': 'Чистые номера и ванные комнаты.',
#        'confidence': 0,
#        'category_id_list': ['f63a', '343c'],
#        'sentiment': 'pos'},
#       {'text': 'В хостеле чисто.',
#        'confidence': 0,
#        'category_id_list': ['9f14'],
#        'sentiment': 'pos'}]},
#     {'count': 0.3058,
#      'ratio': 'Good',
#      'score': 97,
#      'review_count': 511,
#      'category_name': 'Сервис',
#      'text': 'Обслуживание по высшему разряду.',
#      'relevance': 1,
#      'sentiment': 'pos',
#      'short_text': 'Фантастическое обслуживание',
#      'category_id': '15',
#      'highlight_list': [{'text': 'Персонал отличный',
#        'confidence': 100,
#        'category_id_list': ['15'],
#        'sentiment': ''},
#       {'text': 'Приветливый персонал',
#        'confidence': 100,
#        'category_id_list': ['ddbc', '15'],
#        'sentiment': ''},
#       {'text': 'Вежливый персонал',
#        'confidence': 100,
#        'category_id_list': ['f8d2', '15'],
#        'sentiment': ''}],
#      'sub_category_list': [{'count': 0.1712,
#        'ratio': '',
#        'score': 100,
#        'review_count': 286,
#        'category_name': 'Дружелюбие',
#        'text': '100% отметили, что персонал очень приветливый.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Приветливый персонал',
#        'category_id': 'ddbc',
#        'highlight_list': [{'text': 'Приветливый персонал',
#          'confidence': 100,
#          'category_id_list': ['ddbc', '15'],
#          'sentiment': ''},
#         {'text': 'Приветливые ребята',
#          'confidence': 100,
#          'category_id_list': ['ddbc', '15'],
#          'sentiment': ''},
#         {'text': 'Доброжелательные администраторы',
#          'confidence': 100,
#          'category_id_list': ['ddbc', '15'],
#          'sentiment': ''}]},
#       {'count': 0.0227,
#        'ratio': '',
#        'score': 95,
#        'review_count': 38,
#        'category_name': 'Профессионализм',
#        'text': '95% отметили, что обслуживание высокопрофессиональное.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Профессиональное обслуживание',
#        'category_id': 'f8d2',
#        'highlight_list': [{'text': 'Вежливый персонал',
#          'confidence': 100,
#          'category_id_list': ['f8d2', '15'],
#          'sentiment': ''},
#         {'text': 'Вежливым персоналом',
#          'confidence': 100,
#          'category_id_list': ['f8d2', '15'],
#          'sentiment': ''},
#         {'text': 'Заселили быстро',
#          'confidence': 100,
#          'category_id_list': ['f8d2', '15b', '15'],
#          'sentiment': ''}]},
#       {'count': 0.0221,
#        'ratio': '',
#        'score': 92,
#        'review_count': 37,
#        'category_name': 'Ресепшн',
#        'text': '92% отметили, что персонал регистрации прекрасный.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Прекрасный персонал регистрации',
#        'category_id': '15b',
#        'highlight_list': [{'text': 'Заселили быстро',
#          'confidence': 100,
#          'category_id_list': ['f8d2', '15b', '15'],
#          'sentiment': ''},
#         {'text': 'Ресепшен неплохо',
#          'confidence': 100,
#          'category_id_list': ['15b', '15'],
#          'sentiment': ''},
#         {'text': 'Теплый прием',
#          'confidence': 100,
#          'category_id_list': ['15b', '15'],
#          'sentiment': ''}]}],
#      'summary_sentence_list': [{'text': 'Приветливый персонал, приятные сотрудники стойки регистрации.',
#        'confidence': 0,
#        'category_id_list': ['15', 'ddbc', 'f8d2', '15b'],
#        'sentiment': 'pos'}]},
#     {'count': 0.0993,
#      'ratio': 'Good',
#      'score': 94,
#      'review_count': 166,
#      'category_name': 'Удобства',
#      'text': 'Отличные удобства.',
#      'relevance': 1.7975156,
#      'sentiment': 'pos',
#      'short_text': 'Отличные удобства',
#      'category_id': '244',
#      'highlight_list': [{'text': 'Бесплатно велосипед',
#        'confidence': 100,
#        'category_id_list': ['244', '20c', '22a'],
#        'sentiment': ''},
#       {'text': 'Отличные условия',
#        'confidence': 100,
#        'category_id_list': ['244'],
#        'sentiment': ''},
#       {'text': 'Приятный дизайн',
#        'confidence': 100,
#        'category_id_list': ['244', 'vdes', '171'],
#        'sentiment': ''}],
#      'sub_category_list': [{'count': 0.0078,
#        'ratio': '',
#        'score': 85,
#        'review_count': 13,
#        'category_name': 'Входной холл',
#        'text': '85% в восторге от вестибюля.',
#        'relevance': 1.11434,
#        'sentiment': 'pos',
#        'short_text': 'Прекрасный вестибюль',
#        'category_id': '24b',
#        'highlight_list': []},
#       {'count': 0.0042,
#        'ratio': '',
#        'score': 100,
#        'review_count': 7,
#        'category_name': 'Спортивное оборудование на открытом воздухе',
#        'text': '100% в восторге от спортивных площадок.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Хорошие спортивные площадки',
#        'category_id': '20c',
#        'highlight_list': [{'text': 'Велосипеды бесплатно',
#          'confidence': 100,
#          'category_id_list': ['244', '20c', '22a'],
#          'sentiment': ''},
#         {'text': 'Бесплатно велосипед',
#          'confidence': 100,
#          'category_id_list': ['244', '20c', '22a'],
#          'sentiment': ''},
#         {'text': 'Бесплатным игровым автоматом Футбол',
#          'confidence': 100,
#          'category_id_list': ['244', '20c', '22a'],
#          'sentiment': ''}]}],
#      'summary_sentence_list': [{'text': 'Шикарная зона лобби, отличные условия для спорта.',
#        'confidence': 0,
#        'category_id_list': ['244', '20c', '24b'],
#        'sentiment': 'pos'}]},
#     {'count': 0.2172,
#      'ratio': 'Good',
#      'score': 91,
#      'review_count': 363,
#      'category_name': 'Номер',
#      'text': 'Номера великолепные.',
#      'relevance': 1.317558,
#      'sentiment': 'pos',
#      'short_text': 'Прекрасный номер',
#      'category_id': '11',
#      'highlight_list': [{'text': 'Прекрасный диван',
#        'confidence': 100,
#        'category_id_list': ['11', '11i'],
#        'sentiment': ''},
#       {'text': 'Просторные комнаты',
#        'confidence': 100,
#        'category_id_list': ['11', '4b72', '111'],
#        'sentiment': ''},
#       {'text': 'Отличный номер',
#        'confidence': 100,
#        'category_id_list': ['11'],
#        'sentiment': ''}],
#      'sub_category_list': [{'count': 0.0569,
#        'ratio': '',
#        'score': 90,
#        'review_count': 95,
#        'category_name': 'Кровати',
#        'text': '90% отметили, что кровати удобные.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Удобные кровати',
#        'category_id': '11b',
#        'highlight_list': [{'text': 'Новое пастельное белье',
#          'confidence': 100,
#          'category_id_list': ['11', 'ae0f', 'vmod', '11b', '111', '171'],
#          'sentiment': ''},
#         {'text': 'Удобная кровать',
#          'confidence': 100,
#          'category_id_list': ['11', '111', '11b'],
#          'sentiment': ''},
#         {'text': 'Кровати широкие',
#          'confidence': 100,
#          'category_id_list': ['11', '4b72', '111', '11b'],
#          'sentiment': ''}]},
#       {'count': 0.0497,
#        'ratio': '',
#        'score': 82,
#        'review_count': 83,
#        'category_name': 'Ванная комната',
#        'text': '82% довольны санузлом.',
#        'relevance': 1.1851938,
#        'sentiment': 'pos',
#        'short_text': 'Впечатляющий санузел',
#        'category_id': '11a',
#        'highlight_list': [{'text': 'Большие полотенца',
#          'confidence': 100,
#          'category_id_list': ['11', '111', '11a', '5b6c', '4b72'],
#          'sentiment': ''},
#         {'text': 'Душевых много',
#          'confidence': 100,
#          'category_id_list': ['11m', '11', '11a'],
#          'sentiment': ''},
#         {'text': 'Превосходный санузел',
#          'confidence': 100,
#          'category_id_list': ['11', '11a'],
#          'sentiment': ''}]},
#       {'count': 0.058,
#        'ratio': '',
#        'score': 86,
#        'review_count': 97,
#        'category_name': 'Размер номера',
#        'text': '86% отметили, что номера просторные.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Просторные номера',
#        'category_id': '4b72',
#        'highlight_list': [{'text': 'Большие полотенца',
#          'confidence': 100,
#          'category_id_list': ['11', '111', '11a', '5b6c', '4b72'],
#          'sentiment': ''},
#         {'text': 'Большом диване',
#          'confidence': 100,
#          'category_id_list': ['11', '111', '11i', '4b72'],
#          'sentiment': ''},
#         {'text': 'Кровати большие',
#          'confidence': 100,
#          'category_id_list': ['11', '4b72', '111', '11b'],
#          'sentiment': ''}]},
#       {'count': 0.0497,
#        'ratio': '',
#        'score': 100,
#        'review_count': 83,
#        'category_name': 'Кухня',
#        'text': '100% отметили, что мини-кухня хорошая.',
#        'relevance': 3.8762882,
#        'sentiment': 'pos',
#        'short_text': 'Хорошая мини-кухня',
#        'category_id': '11j',
#        'highlight_list': [{'text': 'Неплохая кухня',
#          'confidence': 100,
#          'category_id_list': ['11', '11j'],
#          'sentiment': ''},
#         {'text': 'Хорошая кухня',
#          'confidence': 100,
#          'category_id_list': ['11', '11j'],
#          'sentiment': ''}]},
#       {'count': 0.0431,
#        'ratio': '',
#        'score': 97,
#        'review_count': 72,
#        'category_name': 'Чистота в номере',
#        'text': '97% отметили, что номера чистые.',
#        'relevance': 1.0230029,
#        'sentiment': 'pos',
#        'short_text': 'Чистые номера',
#        'category_id': 'f63a',
#        'highlight_list': [{'text': 'Номера чистые',
#          'confidence': 100,
#          'category_id_list': ['11', 'f63a', '333'],
#          'sentiment': ''},
#         {'text': 'Чистейшие номера',
#          'confidence': 100,
#          'category_id_list': ['f63a', '11', '333'],
#          'sentiment': ''},
#         {'text': 'Чистый санузел',
#          'confidence': 100,
#          'category_id_list': ['11', 'f63a', '343c', '11a', '333'],
#          'sentiment': ''}]},
#       {'count': 0.0132,
#        'ratio': '',
#        'score': 90,
#        'review_count': 22,
#        'category_name': 'Чистота ванной комнаты',
#        'text': '90% отметили, что санузел чистый.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Чистый санузел',
#        'category_id': '343c',
#        'highlight_list': [{'text': 'Чистый санузел',
#          'confidence': 100,
#          'category_id_list': ['11', 'f63a', '343c', '11a', '333'],
#          'sentiment': ''}]},
#       {'count': 0.0156,
#        'ratio': '',
#        'score': 82,
#        'review_count': 26,
#        'category_name': 'Душ',
#        'text': '82% понравился душ.',
#        'relevance': 1.1183872,
#        'sentiment': 'pos',
#        'short_text': 'Отличный душ',
#        'category_id': '11m',
#        'highlight_list': [{'text': 'Душевых много',
#          'confidence': 100,
#          'category_id_list': ['11m', '11', '11a'],
#          'sentiment': ''},
#         {'text': 'В комнате есть санузел с душем',
#          'confidence': 100,
#          'category_id_list': ['11m', '11', '11a'],
#          'sentiment': ''},
#         {'text': 'Хороший душ',
#          'confidence': 100,
#          'category_id_list': ['11', '11m', '11a'],
#          'sentiment': ''}]},
#       {'count': 0.0168,
#        'ratio': '',
#        'score': 100,
#        'review_count': 28,
#        'category_name': 'Вид',
#        'text': '100% отметили, что вид хороший.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'В восторге от вида',
#        'category_id': '11e',
#        'highlight_list': [{'text': 'Вид из окна замечательный',
#          'confidence': 100,
#          'category_id_list': ['11e', '11'],
#          'sentiment': ''},
#         {'text': 'Прекрасным видом',
#          'confidence': 100,
#          'category_id_list': ['11', '11e'],
#          'sentiment': ''},
#         {'text': 'Красивый вид',
#          'confidence': 100,
#          'category_id_list': ['11e', '11'],
#          'sentiment': ''}]},
#       {'count': 0.0102,
#        'ratio': '',
#        'score': 81,
#        'review_count': 17,
#        'category_name': 'Мебель',
#        'text': '81% довольны мебелью.',
#        'relevance': 1.0115403,
#        'sentiment': 'pos',
#        'short_text': 'Хорошая мебель',
#        'category_id': '11i',
#        'highlight_list': [{'text': 'Прекрасный диван',
#          'confidence': 100,
#          'category_id_list': ['11', '11i'],
#          'sentiment': ''},
#         {'text': 'Большим столом',
#          'confidence': 100,
#          'category_id_list': ['11', '111', '11i', '4b72'],
#          'sentiment': ''},
#         {'text': 'Большом диване',
#          'confidence': 100,
#          'category_id_list': ['11', '111', '11i', '4b72'],
#          'sentiment': ''}]},
#       {'count': 0.0078,
#        'ratio': '',
#        'score': 88,
#        'review_count': 13,
#        'category_name': 'Балкон',
#        'text': '88% порадовались балкону.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Отличный балкон',
#        'category_id': '11d',
#        'highlight_list': []},
#       {'count': 0.0108,
#        'ratio': '',
#        'score': 58,
#        'review_count': 18,
#        'category_name': 'Размер ванной комнаты',
#        'text': '58% отметили, что санузел достаточно просторный.',
#        'relevance': 1,
#        'sentiment': 'neu',
#        'short_text': 'Ванная среднего размера',
#        'category_id': '5b6c',
#        'highlight_list': [{'text': 'Большие полотенца',
#          'confidence': 100,
#          'category_id_list': ['11', '111', '11a', '5b6c', '4b72'],
#          'sentiment': ''},
#         {'text': 'Огромная ванная',
#          'confidence': 100,
#          'category_id_list': ['11', '4b72', '111', '11a', '5b6c'],
#          'sentiment': ''},
#         {'text': 'Просторный санузел',
#          'confidence': 100,
#          'category_id_list': ['11a', '4b72', '111', '5b6c', '11'],
#          'sentiment': ''}]},
#       {'count': 0.0096,
#        'ratio': '',
#        'score': 71,
#        'review_count': 16,
#        'category_name': 'Техническое обслуживание номеров',
#        'text': 'Хорошее состояние, по мнению 71%.',
#        'relevance': 1.186471,
#        'sentiment': 'pos',
#        'short_text': 'Номера в хорошем состоянии',
#        'category_id': 'e51a',
#        'highlight_list': [{'text': 'Хорошо оборудованный номер',
#          'confidence': 100,
#          'category_id_list': ['e51a', '11'],
#          'sentiment': ''}]},
#       {'count': 0.0036,
#        'ratio': '',
#        'score': 58,
#        'review_count': 6,
#        'category_name': 'Телевизор',
#        'text': 'Только для 58% телевизор приемлемый.',
#        'relevance': 1,
#        'sentiment': 'neu',
#        'short_text': 'Стандартный телевизор',
#        'category_id': '11h',
#        'highlight_list': [{'text': 'В комнате нет телевизора',
#          'confidence': 100,
#          'category_id_list': ['11', '11h'],
#          'sentiment': ''}]},
#       {'count': 0.003,
#        'ratio': '',
#        'score': 0,
#        'review_count': 5,
#        'category_name': 'Кондиционер',
#        'text': 'Кондиционером недовольны 100%.',
#        'relevance': 1,
#        'sentiment': 'neg',
#        'short_text': 'Кондиционер довольно старый',
#        'category_id': '11f',
#        'highlight_list': []},
#       {'count': 0.003,
#        'ratio': '',
#        'score': 100,
#        'review_count': 5,
#        'category_name': 'Старый/Новый номер',
#        'text': '100% понравились современные номера.',
#        'relevance': 1.178594,
#        'sentiment': 'pos',
#        'short_text': 'Новые номера',
#        'category_id': 'ae0f',
#        'highlight_list': [{'text': 'Новое пастельное белье',
#          'confidence': 100,
#          'category_id_list': ['11', 'ae0f', 'vmod', '11b', '111', '171'],
#          'sentiment': ''}]}],
#      'summary_sentence_list': [{'text': 'Современные номера с прекрасной мебелью и мини-кухней.',
#        'confidence': 0,
#        'category_id_list': ['11i', 'ae0f', '11j', '11'],
#        'sentiment': 'pos'},
#       {'text': 'Просторные, аккуратные номера с отличными кроватями. Кондиционер работает плохо.',
#        'confidence': 0,
#        'category_id_list': ['4b72', '11b', 'f63a', '11f'],
#        'sentiment': 'mixed'},
#       {'text': 'Чистые, достаточно большие ванные комнаты.',
#        'confidence': 0,
#        'category_id_list': ['11a', '5b6c', '343c'],
#        'sentiment': 'mixed'},
#       {'text': 'Номера в хорошем состоянии с красивым видом с балкона.',
#        'confidence': 0,
#        'category_id_list': ['11d', '11e', 'e51a'],
#        'sentiment': 'pos'},
#       {'text': 'Отличный душ.',
#        'confidence': 0,
#        'category_id_list': ['11m'],
#        'sentiment': 'pos'},
#       {'text': 'Стандартный телевизор.',
#        'confidence': 0,
#        'category_id_list': ['11h'],
#        'sentiment': 'neu'}]},
#     {'count': 0.1089,
#      'ratio': 'Good',
#      'score': 83,
#      'review_count': 182,
#      'category_name': 'Комфорт',
#      'text': 'Высокий уровень комфорта.',
#      'relevance': 1.028437,
#      'sentiment': 'pos',
#      'short_text': 'Довольно комфортабельно.',
#      'category_id': '111',
#      'highlight_list': [{'text': 'Просторные комнаты',
#        'confidence': 100,
#        'category_id_list': ['11', '4b72', '111'],
#        'sentiment': ''},
#       {'text': 'Удобная кровать',
#        'confidence': 100,
#        'category_id_list': ['11', '111', '11b'],
#        'sentiment': ''},
#       {'text': 'Огромная ванная',
#        'confidence': 100,
#        'category_id_list': ['11', '4b72', '111', '11a', '5b6c'],
#        'sentiment': ''}],
#      'sub_category_list': [{'count': 0.0569,
#        'ratio': '',
#        'score': 90,
#        'review_count': 95,
#        'category_name': 'Кровати',
#        'text': '90% отметили, что кровати удобные.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Удобные кровати',
#        'category_id': '11b',
#        'highlight_list': [{'text': 'Новое пастельное белье',
#          'confidence': 100,
#          'category_id_list': ['11', 'ae0f', 'vmod', '11b', '111', '171'],
#          'sentiment': ''},
#         {'text': 'Удобная кровать',
#          'confidence': 100,
#          'category_id_list': ['11', '111', '11b'],
#          'sentiment': ''},
#         {'text': 'Кровати широкие',
#          'confidence': 100,
#          'category_id_list': ['11', '4b72', '111', '11b'],
#          'sentiment': ''}]},
#       {'count': 0.058,
#        'ratio': '',
#        'score': 86,
#        'review_count': 97,
#        'category_name': 'Размер номера',
#        'text': '86% отметили, что номера просторные.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Просторные номера',
#        'category_id': '4b72',
#        'highlight_list': [{'text': 'Большие полотенца',
#          'confidence': 100,
#          'category_id_list': ['11', '111', '11a', '5b6c', '4b72'],
#          'sentiment': ''},
#         {'text': 'Большом диване',
#          'confidence': 100,
#          'category_id_list': ['11', '111', '11i', '4b72'],
#          'sentiment': ''},
#         {'text': 'Кровати большие',
#          'confidence': 100,
#          'category_id_list': ['11', '4b72', '111', '11b'],
#          'sentiment': ''}]},
#       {'count': 0.0174,
#        'ratio': '',
#        'score': 66,
#        'review_count': 29,
#        'category_name': 'Шум',
#        'text': 'Только для 66% уровень шума приемлемый.',
#        'relevance': 1,
#        'sentiment': 'neu',
#        'short_text': 'Приемлемый уровень шума',
#        'category_id': '111a',
#        'highlight_list': [{'text': 'Шумная дверь',
#          'confidence': 100,
#          'category_id_list': ['11', '111a', '111'],
#          'sentiment': ''},
#         {'text': 'Номерах тихо',
#          'confidence': 100,
#          'category_id_list': ['111a', '11', '111'],
#          'sentiment': ''},
#         {'text': 'Нет шума',
#          'confidence': 100,
#          'category_id_list': ['111a', '111'],
#          'sentiment': ''}]},
#       {'count': 0.0108,
#        'ratio': '',
#        'score': 58,
#        'review_count': 18,
#        'category_name': 'Размер ванной комнаты',
#        'text': '58% отметили, что санузел достаточно просторный.',
#        'relevance': 1,
#        'sentiment': 'neu',
#        'short_text': 'Ванная среднего размера',
#        'category_id': '5b6c',
#        'highlight_list': [{'text': 'Большие полотенца',
#          'confidence': 100,
#          'category_id_list': ['11', '111', '11a', '5b6c', '4b72'],
#          'sentiment': ''},
#         {'text': 'Огромная ванная',
#          'confidence': 100,
#          'category_id_list': ['11', '4b72', '111', '11a', '5b6c'],
#          'sentiment': ''},
#         {'text': 'Просторный санузел',
#          'confidence': 100,
#          'category_id_list': ['11a', '4b72', '111', '5b6c', '11'],
#          'sentiment': ''}]},
#       {'count': 0.003,
#        'ratio': '',
#        'score': 0,
#        'review_count': 5,
#        'category_name': 'Кондиционер',
#        'text': 'Кондиционером недовольны 100%.',
#        'relevance': 1,
#        'sentiment': 'neg',
#        'short_text': 'Кондиционер довольно старый',
#        'category_id': '11f',
#        'highlight_list': []}],
#      'summary_sentence_list': [{'text': 'Номера отличного размера, очень комфортабельные, с прекрасными кроватями.',
#        'confidence': 0,
#        'category_id_list': ['111', '4b72', '11b'],
#        'sentiment': 'pos'},
#       {'text': 'Достаточно тихие номера с ванными комнатами хорошего размера. Кондиционер работает плохо.',
#        'confidence': 0,
#        'category_id_list': ['111a', '11f', '5b6c'],
#        'sentiment': 'mixed'}]},
#     {'count': 0.018,
#      'ratio': 'Good',
#      'score': 79,
#      'review_count': 30,
#      'category_name': 'Интернет',
#      'text': 'Интернет работал.',
#      'relevance': 1,
#      'sentiment': 'pos',
#      'short_text': 'Хороший интернет',
#      'category_id': '18',
#      'highlight_list': [{'text': 'Бесплатный вайфай',
#        'confidence': 100,
#        'category_id_list': ['805b', '22a', '18'],
#        'sentiment': ''},
#       {'text': 'Бесплатный Wi-Fi',
#        'confidence': 100,
#        'category_id_list': ['18', '22a', '805b'],
#        'sentiment': ''},
#       {'text': 'Хорошее wifi-подключение',
#        'confidence': 100,
#        'category_id_list': ['18', 'wifq'],
#        'sentiment': ''}],
#      'sub_category_list': [],
#      'summary_sentence_list': [{'text': 'Хороший интернет.',
#        'confidence': 0,
#        'category_id_list': ['18'],
#        'sentiment': 'pos'}]},
#     {'count': 0.0162,
#      'ratio': 'Good',
#      'score': 76,
#      'review_count': 27,
#      'category_name': 'Завтрак',
#      'text': 'Хороший завтрак.',
#      'relevance': 1,
#      'sentiment': 'pos',
#      'short_text': 'Вкусный завтрак',
#      'category_id': '131',
#      'highlight_list': [{'text': 'Сладкая выпечка',
#        'confidence': 100,
#        'category_id_list': ['131'],
#        'sentiment': ''},
#       {'text': 'Вареньем Милые',
#        'confidence': 100,
#        'category_id_list': ['131'],
#        'sentiment': ''},
#       {'text': 'Вкусные завтраки',
#        'confidence': 100,
#        'category_id_list': ['131'],
#        'sentiment': ''}],
#      'sub_category_list': [{'count': 0.0042,
#        'ratio': '',
#        'score': 100,
#        'review_count': 7,
#        'category_name': 'Стоимость завтрака',
#        'text': '100% порадовались ценам на завтрак.',
#        'relevance': 1,
#        'sentiment': 'pos',
#        'short_text': 'Привлекательные цены на завтрак',
#        'category_id': 'ba62',
#        'highlight_list': [{'text': 'Бесплатно завтрак',
#          'confidence': 100,
#          'category_id_list': ['131', '22a', 'ba62'],
#          'sentiment': ''}]}],
#      'summary_sentence_list': [{'text': 'Отличный завтрак по доступным ценам.',
#        'confidence': 0,
#        'category_id_list': ['131', 'ba62'],
#        'sentiment': 'pos'}]}],
#    'language_split': {'de': {'percentage': 2},
#     'en': {'percentage': 36},
#     'es': {'percentage': 6},
#     'fr': {'percentage': 3},
#     'it': {'percentage': 1},
#     'ja': {'percentage': 1},
#     'ko': {'percentage': 12},
#     'pt': {'percentage': 3},
#     'ru': {'percentage': 31},
#     'zh': {'percentage': 5}},
#    'trip_type_split': {'trip_type_split': {'couple': 7,
#      'family': 9,
#      'solo': 84}},
#    'summary': {'reviews_count': 1671,
#     'score': 97,
#     'popularity': 1,
#     'text': 'Идеальный хостел для индивидуальных путешественников. Удобно осматривать достопримечательности, рядом с ресторанами и барами. Прекрасный номер. Великолепная атмосфера.'}}},
#  'hotels_suggests': [],
#  'hotels_by_id': {},
#  'room_types': {},
#  'discounts': {},
#  'expire_at': '1741181631',
#  'ttl': 86399,
#  'selected_hotels_ids': []}

# %%
df_single_hotel = extract_full_hotel_data("hotellook_single_1198039.json")
df_single_hotel
# Out:
#         id                          name                address  location_id  \
# 0  1198039  Sunflower Авеню Отель Москва  Ул. Щепкина 32, стр.1        12153
#
#    latitude  longitude  stars  rating  reviews_count  min_price  ...  \
# 0   55.7796   37.62982      3     8.9           3195         35  ...
#
#    popularity  popularity2 trending_speed  \
# 0      610449         1399              0
#
#                                           photos_ids  \
# 0  [8693498484, 8693498482, 8693498477, 869349848...
#
#                                       pois_distances  \
# 0  {'69873': 28861, '69874': 43984, '69885': 2465...
#
#                              nearest_poi_by_category       districts_ids  \
# 0  {'airport': 69885, 'metro_station': 71913, 'tr...  [1667834, 1676723]
#
#   weights scoring  debug_info
# 0      {}      {}
#
# [1 rows x 31 columns]

# %% [markdown]
# Как мы и предполагали, данные во время общего запроса и в виде отдельного запроса ничем не отличаются - те же столбцы и те же данные. Это значительно упрощает нашу работу

# %% [markdown]
# Начнем полноценно выкачивать данные из API, настроив limit и указав неколько городов. До этого по умолчанию у нас стоял город с id 12153, это Москва. Но на сайте hotellooks есть и другие локации: Санкт-Петербург, Сочи, Анапа. В этих городах сравнительно большое количество отелей. Отели других в городах России в базе данных hotellook немногочисленны  (Владивосток - 252 отеля, Владикавказ - 91 отель, Владимир - 63 отеля, Тула - 67 отелей, Нижний Новгород - 242 отеля, Ростов-на-Дону - 253 отеля).
#
# Поскольку городов с большим числом (>1000 отелей) отелей немного, позволим вручную найти id данных городов

# %%
# 12153 - Москва, всего 9 163 значений
# 12196 - Санкт-Петербург, 13 173 значений
# 12193 - Сочи, 14 220 значений
# 12099 - Анапа, 5 565 значений
 
get_all_hotellook_data(limit=50000, location_id=[12153, 12196, 12193, 12099])
# Out:
# Данные загружены в hotellook.json. Число запросов: 50000

# %%
file_path = "hotellook_alldata_limit-50000.json"
df_full_hotels = extract_full_hotel_data(file_path)
df_full_hotels
# Out:
#                id                                               name  \
# 0      1250022545                     Мини-Отель Мопс на Рубинштейна
# 1       964250854                                Мини Отель Mushroom
# 2          333570                               Отель Вега Измайлово
# 3        21120269                                      Версаль Отель
# 4      1910372927                                       Отель Реноме
# ...           ...                                                ...
# 42117  1915703569           2-комн. квартира, 40 кв.м. на 4 человека
# 42118  1915947571           1-комн. квартира, 25 кв.м. на 3 человека
# 42119  1915663041           1-комн. квартира, 25 кв.м. на 3 человека
# 42120  1915723179                               3-комнатная квартира
# 42121  1910167251  Брусовый дом 120 кв. м. у Моря в Лазаревском с...
#
#                                         address  location_id   latitude  \
# 0      улица Рубинштейна, д.12, Санкт-Петербург        12196  59.931152
# 1               Набережная Канала Грибоедова,42        12196  59.930200
# 2             Измайловское шоссе 71 строение 3В        12153  55.790752
# 3                             ул.Восстания д.12        12196  59.936010
# 4                            Гончарная улица 26        12196  59.928090
# ...                                         ...          ...        ...
# 42117                       Воскресенская, 14/1        12193  43.402145
# 42118                 Воскресенская улица, 14/1        12193  43.402195
# 42119                   Воскресенская улица, 14        12193  43.398132
# 42120             Нижнеимеретинская улица, 137А        12193  43.397510
# 42121             Макопсе, ул. Греческая , 20/1        12193  43.996765
#
#        longitude  stars  rating  reviews_count  min_price  ...  popularity  \
# 0      30.345670      3     9.2            498         19  ...       69104
# 1      30.319010      3     9.3              0         17  ...       69103
# 2      37.747135      4     9.0          15712         46  ...       69102
# 3      30.360070      3     9.2            415         27  ...       69101
# 4      30.369590      4     9.1              0         23  ...       69099
# ...          ...    ...     ...            ...        ...  ...         ...
# 42117  39.979725      0     0.0              0        193  ...         121
# 42118  39.979725      0     0.0              0        185  ...         120
# 42119  39.980553      0     0.0              0        173  ...         118
# 42120  39.968616      0     0.0              0        109  ...         113
# 42121  39.207077      0     0.0              0        111  ...          24
#
#        popularity2 trending_speed  \
# 0              291            1.6
# 1              232            0.0
# 2             2268            0.0
# 3              107            0.0
# 4              566            0.0
# ...            ...            ...
# 42117            0            0.0
# 42118            0            0.0
# 42119            0            0.0
# 42120            0            0.0
# 42121            0            0.0
#
#                                               photos_ids  \
# 0      [7515131692, 8286984314, 7515134055, 751513409...
# 1      [7510410856, 9611111725, 9400656506, 940065650...
# 2      [7489913361, 8352837505, 8352837517, 748991281...
# 3      [7743613705, 7743613701, 7743613699, 651834590...
# 4      [9011295402, 9011295366, 9011295384, 901129539...
# ...                                                  ...
# 42117  [9686324383, 9686324384, 9686324385, 968632438...
# 42118  [9702267731, 9702267732, 9702267733, 970226773...
# 42119   [9665066098, 9665066099, 9665066100, 9665066101]
# 42120  [9686705995, 9719167368, 9719167369, 971916737...
# 42121  [8845123226, 8845123227, 8845123228, 884512322...
#
#                                           pois_distances  \
# 0      {'71006': 14062, '71781': 732, '71817': 433, '...
# 1      {'71006': 13814, '71842': 422, '71862': 405, '...
# 2      {'69873': 35331, '69874': 42911, '69885': 2839...
# 3      {'71006': 14733, '71817': 1158, '71843': 577, ...
# 4      {'71006': 13991, '71753': 1003, '71843': 884, ...
# ...                                                  ...
# 42117  {'71130': 6056, '302866': 974, '302867': 1978,...
# 42118  {'71130': 6052, '302866': 978, '302867': 1983,...
# 42119  {'71130': 6475, '302866': 681, '302867': 1554,...
# 42120  {'71130': 6124, '302866': 59, '302867': 2169, ...
# 42121  {'71130': 84802, '295920': 2410, '300661': 400...
#
#                                  nearest_poi_by_category  \
# 0      {'airport': 71006, 'beach': 346587, 'metro_sta...
# 1      {'airport': 71006, 'beach': 346587, 'metro_sta...
# 2      {'airport': 69885, 'metro_station': 72010, 'tr...
# 3      {'airport': 71006, 'beach': 346587, 'metro_sta...
# 4      {'airport': 71006, 'beach': 346587, 'metro_sta...
# ...                                                  ...
# 42117                {'airport': 71130, 'beach': 302866}
# 42118                {'airport': 71130, 'beach': 302866}
# 42119                {'airport': 71130, 'beach': 302866}
# 42120                {'airport': 71130, 'beach': 302866}
# 42121                {'airport': 71130, 'beach': 295920}
#
#                    districts_ids                  weights scoring  debug_info
# 0                      [1664298]   {'default': 2.2985132}      {}
# 1                      [1416598]   {'default': 2.0068567}      {}
# 2                      [1416636]   {'default': 2.2766292}      {}
# 3                      [1664298]   {'default': 2.1939864}      {}
# 4                      [1664298]   {'default': 2.1731336}      {}
# ...                          ...                      ...     ...         ...
# 42117  [12096, 1672960, 1676737]  {'default': 0.17178896}      {}
# 42118  [12096, 1672960, 1676737]  {'default': 0.17178896}      {}
# 42119  [12096, 1672960, 1676737]  {'default': 0.17178896}      {}
# 42120  [12096, 1672960, 1676737]  {'default': 0.17178896}      {}
# 42121                  [1676737]  {'default': 0.16927806}      {}
#
# [42122 rows x 31 columns]

# %%
df_full_hotels.to_csv("hotellook.csv", index=False)
